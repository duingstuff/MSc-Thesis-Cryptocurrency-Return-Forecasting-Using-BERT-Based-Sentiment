# %% [markdown]
# ## Cryptocurrency Price Scraping from Yahoo Finance

# %%
pip install yfinance

# %%
import pandas as pd, numpy as np
import yfinance as yf

# select desired time period
start = "2019-01-01"
end   = "2022-02-18"

# %%
df_financial = yf.download("ETH-USD",  # or input "BTC-USD"
                     #period = "1Y",
                      start= start, 
                      end= end, 
                      interval = "1d",
                      progress=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_financial
# Out:
#                    Open         High  ...    Adj Close       Volume
# Date                                  ...
# 2019-01-01   133.418152   141.397507  ...   140.819412   2258709868
# 2019-01-02   141.519516   156.929138  ...   155.047684   3328240369
# 2019-01-03   155.196045   155.863052  ...   149.135010   2676164880
# 2019-01-04   148.912888   156.878983  ...   154.581940   3126192535
# 2019-01-05   154.337418   160.824890  ...   155.638596   3338211928
# ...                 ...          ...  ...          ...          ...
# 2022-02-14  2880.187744  2957.963623  ...  2933.479004  12164552172
# 2022-02-15  2933.729004  3185.520752  ...  3179.877197  13921257873
# 2022-02-16  3180.446777  3181.616943  ...  3127.830078  12352406833
# 2022-02-17  3126.858398  3154.615234  ...  2881.481934  15860206214
# 2022-02-18  2883.413086  2936.811279  ...  2888.457764  14635136000
#
# [1145 rows x 6 columns]

# %%
from google.colab import files, drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
df_financial.to_csv("/drive/My Drive/Colab Notebooks/thesis_all_datasets/eth_all_prive.csv", header=True, index=True, columns=list(df_financial.columns))
